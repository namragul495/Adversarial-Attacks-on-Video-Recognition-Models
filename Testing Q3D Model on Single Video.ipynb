# %%
# -*- coding:utf-8 -*-
import tensorflow as tf
from tensorflow import keras
import numpy as np
import random
import cv2
import os

orignal =[]
prediction = []

# %%
#Read all test videos
f= 'sample_images_RA'
Test_videos =[]
test_list = open('Labels/test.txt','r')
for line in test_list:
    name = line.split(" ")[0]
    orignal.append(line.split(" ")[-1])
    Test_videos.append(f+"/"+name)

# %%
#To load pre-trained model, trained on 5 classes 
model = tf.keras.models.load_model('Trained Models/model_Q3D.h5',compile=False)
#model.summary()
# Out:
# Model: "ResNet_NLP3DC"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 112, 3  0           []
#                                 2, 3)]
#
#  zero_padding3d_1 (ZeroPadding3  (None, 118, 118, 38  0          ['input_1[0][0]']
#  D)                             , 3)
#
#  conv1 (Conv3D)                 (None, 56, 56, 16,   65920       ['zero_padding3d_1[0][0]']
#                                 64)
#
#  bn_conv1 (BatchNormalization)  (None, 56, 56, 16,   64          ['conv1[0][0]']
#                                 64)
#
#  activation_1 (Activation)      (None, 56, 56, 16,   0           ['bn_conv1[0][0]']
#                                 64)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 27, 27, 16,   0          ['activation_1[0][0]']
#                                 64)
#
#  res2a_branch2a (Conv3D)        (None, 14, 14, 8, 6  4160        ['max_pooling3d_1[0][0]']
#                                 4)
#
#  bn2a_branch2a (BatchNormalizat  (None, 14, 14, 8, 6  32         ['res2a_branch2a[0][0]']
#  ion)                           4)
#
#  activation_2 (Activation)      (None, 14, 14, 8, 6  0           ['bn2a_branch2a[0][0]']
#                                 4)
#
#  res2a_branch2b (Conv3D)        (None, 14, 14, 8, 6  36928       ['activation_2[0][0]']
#                                 4)
#
#  bn2a_branch2b (BatchNormalizat  (None, 14, 14, 8, 6  32         ['res2a_branch2b[0][0]']
#  ion)                           4)
#
#  activation_3 (Activation)      (None, 14, 14, 8, 6  0           ['bn2a_branch2b[0][0]']
#                                 4)
#
#  res2a_branch2c (Conv3D)        (None, 14, 14, 8, 6  12352       ['activation_3[0][0]']
#                                 4)
#
#  bn2a_branch2c (BatchNormalizat  (None, 14, 14, 8, 6  32         ['res2a_branch2c[0][0]']
#  ion)                           4)
#
#  activation_4 (Activation)      (None, 14, 14, 8, 6  0           ['bn2a_branch2c[0][0]']
#                                 4)
#
#  res2a_branch2d (Conv3D)        (None, 14, 14, 8, 6  36928       ['activation_4[0][0]']
#                                 4)
#
#  bn2a_branch2d (BatchNormalizat  (None, 14, 14, 8, 6  32         ['res2a_branch2d[0][0]']
#  ion)                           4)
#
#  activation_5 (Activation)      (None, 14, 14, 8, 6  0           ['bn2a_branch2d[0][0]']
#                                 4)
#
#  res2a_branch2e (Conv3D)        (None, 14, 14, 8, 6  36928       ['activation_5[0][0]']
#                                 4)
#
#  bn2a_branch2e (BatchNormalizat  (None, 14, 14, 8, 6  32         ['res2a_branch2e[0][0]']
#  ion)                           4)
#
#  activation_6 (Activation)      (None, 14, 14, 8, 6  0           ['bn2a_branch2e[0][0]']
#                                 4)
#
#  res2a_branch2f (Conv3D)        (None, 14, 14, 8, 2  16640       ['activation_6[0][0]']
#                                 56)
#
#  res2a_branch1 (Conv3D)         (None, 14, 14, 8, 2  16640       ['max_pooling3d_1[0][0]']
#                                 56)
#
#  bn2a_branch2f (BatchNormalizat  (None, 14, 14, 8, 2  32         ['res2a_branch2f[0][0]']
#  ion)                           56)
#
#  bn2a_branch1 (BatchNormalizati  (None, 14, 14, 8, 2  32         ['res2a_branch1[0][0]']
#  on)                            56)
#
#  add_1 (Add)                    (None, 14, 14, 8, 2  0           ['bn2a_branch2f[0][0]',
#                                 56)                               'bn2a_branch1[0][0]']
#
#  activation_7 (Activation)      (None, 14, 14, 8, 2  0           ['add_1[0][0]']
#                                 56)
#
#  res2b_branch2a (Conv3D)        (None, 14, 14, 8, 6  16448       ['activation_7[0][0]']
#                                 4)
#
#  bn2b_branch2a (BatchNormalizat  (None, 14, 14, 8, 6  32         ['res2b_branch2a[0][0]']
#  ion)                           4)
#
#  activation_8 (Activation)      (None, 14, 14, 8, 6  0           ['bn2b_branch2a[0][0]']
#                                 4)
#
#  res2b_branch2b (Conv3D)        (None, 14, 14, 8, 6  36928       ['activation_8[0][0]']
#                                 4)
#
#  bn2b_branch2b (BatchNormalizat  (None, 14, 14, 8, 6  32         ['res2b_branch2b[0][0]']
#  ion)                           4)
#
#  activation_9 (Activation)      (None, 14, 14, 8, 6  0           ['bn2b_branch2b[0][0]']
#                                 4)
#
#  res2b_branch2c (Conv3D)        (None, 14, 14, 8, 6  12352       ['activation_9[0][0]']
#                                 4)
#
#  bn2b_branch2c (BatchNormalizat  (None, 14, 14, 8, 6  32         ['res2b_branch2c[0][0]']
#  ion)                           4)
#
#  activation_10 (Activation)     (None, 14, 14, 8, 6  0           ['bn2b_branch2c[0][0]']
#                                 4)
#
#  res2b_branch2d (Conv3D)        (None, 14, 14, 8, 6  36928       ['activation_10[0][0]']
#                                 4)
#
#  bn2b_branch2d (BatchNormalizat  (None, 14, 14, 8, 6  32         ['res2b_branch2d[0][0]']
#  ion)                           4)
#
#  activation_11 (Activation)     (None, 14, 14, 8, 6  0           ['bn2b_branch2d[0][0]']
#                                 4)
#
#  res2b_branch2e (Conv3D)        (None, 14, 14, 8, 6  36928       ['activation_11[0][0]']
#                                 4)
#
#  bn2b_branch2e (BatchNormalizat  (None, 14, 14, 8, 6  32         ['res2b_branch2e[0][0]']
#  ion)                           4)
#
#  activation_12 (Activation)     (None, 14, 14, 8, 6  0           ['bn2b_branch2e[0][0]']
#                                 4)
#
#  res2b_branch2f (Conv3D)        (None, 14, 14, 8, 2  16640       ['activation_12[0][0]']
#                                 56)
#
#  res2b_branch1 (Conv3D)         (None, 14, 14, 8, 2  65792       ['activation_7[0][0]']
#                                 56)
#
#  bn2b_branch2f (BatchNormalizat  (None, 14, 14, 8, 2  32         ['res2b_branch2f[0][0]']
#  ion)                           56)
#
#  bn2b_branch1 (BatchNormalizati  (None, 14, 14, 8, 2  32         ['res2b_branch1[0][0]']
#  on)                            56)
#
#  add_2 (Add)                    (None, 14, 14, 8, 2  0           ['bn2b_branch2f[0][0]',
#                                 56)                               'bn2b_branch1[0][0]']
#
#  activation_13 (Activation)     (None, 14, 14, 8, 2  0           ['add_2[0][0]']
#                                 56)
#
#  res3a_branch2a (Conv3D)        (None, 7, 7, 4, 128  32896       ['activation_13[0][0]']
#                                 )
#
#  bn3a_branch2a (BatchNormalizat  (None, 7, 7, 4, 128  16         ['res3a_branch2a[0][0]']
#  ion)                           )
#
#  activation_14 (Activation)     (None, 7, 7, 4, 128  0           ['bn3a_branch2a[0][0]']
#                                 )
#
#  res3a_branch2b (Conv3D)        (None, 7, 7, 4, 128  147584      ['activation_14[0][0]']
#                                 )
#
#  res3a_branch2c (Conv3D)        (None, 7, 7, 4, 128  49280       ['activation_14[0][0]']
#                                 )
#
#  res3a_branch2d (Conv3D)        (None, 7, 7, 4, 128  147584      ['activation_14[0][0]']
#                                 )
#
#  res3a_branch2e (Conv3D)        (None, 7, 7, 4, 128  49280       ['activation_14[0][0]']
#                                 )
#
#  bn3a_branch2b (BatchNormalizat  (None, 7, 7, 4, 128  16         ['res3a_branch2b[0][0]']
#  ion)                           )
#
#  bn3a_branch2c (BatchNormalizat  (None, 7, 7, 4, 128  16         ['res3a_branch2c[0][0]']
#  ion)                           )
#
#  bn3a_branch2d (BatchNormalizat  (None, 7, 7, 4, 128  16         ['res3a_branch2d[0][0]']
#  ion)                           )
#
#  bn3a_branch2e (BatchNormalizat  (None, 7, 7, 4, 128  16         ['res3a_branch2e[0][0]']
#  ion)                           )
#
#  add_3 (Add)                    (None, 7, 7, 4, 128  0           ['bn3a_branch2b[0][0]',
#                                 )                                 'bn3a_branch2c[0][0]',
#                                                                   'bn3a_branch2d[0][0]',
#                                                                   'bn3a_branch2e[0][0]']
#
#  activation_15 (Activation)     (None, 7, 7, 4, 128  0           ['add_3[0][0]']
#                                 )
#
#  res3a_branch2f (Conv3D)        (None, 7, 7, 4, 512  66048       ['activation_15[0][0]']
#                                 )
#
#  res3a_branch1 (Conv3D)         (None, 7, 7, 4, 512  131584      ['activation_13[0][0]']
#                                 )
#
#  bn3a_branch2f (BatchNormalizat  (None, 7, 7, 4, 512  16         ['res3a_branch2f[0][0]']
#  ion)                           )
#
#  bn3a_branch1 (BatchNormalizati  (None, 7, 7, 4, 512  16         ['res3a_branch1[0][0]']
#  on)                            )
#
#  add_4 (Add)                    (None, 7, 7, 4, 512  0           ['bn3a_branch2f[0][0]',
#                                 )                                 'bn3a_branch1[0][0]']
#
#  activation_16 (Activation)     (None, 7, 7, 4, 512  0           ['add_4[0][0]']
#                                 )
#
#  res3b_branch2a (Conv3D)        (None, 7, 7, 4, 128  65664       ['activation_16[0][0]']
#                                 )
#
#  bn3b_branch2a (BatchNormalizat  (None, 7, 7, 4, 128  16         ['res3b_branch2a[0][0]']
#  ion)                           )
#
#  activation_17 (Activation)     (None, 7, 7, 4, 128  0           ['bn3b_branch2a[0][0]']
#                                 )
#
#  res3b_branch2b (Conv3D)        (None, 7, 7, 4, 128  147584      ['activation_17[0][0]']
#                                 )
#
#  res3b_branch2c (Conv3D)        (None, 7, 7, 4, 128  49280       ['activation_17[0][0]']
#                                 )
#
#  res3b_branch2d (Conv3D)        (None, 7, 7, 4, 128  147584      ['activation_17[0][0]']
#                                 )
#
#  res3b_branch2e (Conv3D)        (None, 7, 7, 4, 128  49280       ['activation_17[0][0]']
#                                 )
#
#  bn3b_branch2b (BatchNormalizat  (None, 7, 7, 4, 128  16         ['res3b_branch2b[0][0]']
#  ion)                           )
#
#  bn3b_branch2c (BatchNormalizat  (None, 7, 7, 4, 128  16         ['res3b_branch2c[0][0]']
#  ion)                           )
#
#  bn3b_branch2d (BatchNormalizat  (None, 7, 7, 4, 128  16         ['res3b_branch2d[0][0]']
#  ion)                           )
#
#  bn3b_branch2e (BatchNormalizat  (None, 7, 7, 4, 128  16         ['res3b_branch2e[0][0]']
#  ion)                           )
#
#  add_5 (Add)                    (None, 7, 7, 4, 128  0           ['bn3b_branch2b[0][0]',
#                                 )                                 'bn3b_branch2c[0][0]',
#                                                                   'bn3b_branch2d[0][0]',
#                                                                   'bn3b_branch2e[0][0]']
#
#  activation_18 (Activation)     (None, 7, 7, 4, 128  0           ['add_5[0][0]']
#                                 )
#
#  res3b_branch2f (Conv3D)        (None, 7, 7, 4, 512  66048       ['activation_18[0][0]']
#                                 )
#
#  res3b_branch1 (Conv3D)         (None, 7, 7, 4, 512  262656      ['activation_16[0][0]']
#                                 )
#
#  bn3b_branch2f (BatchNormalizat  (None, 7, 7, 4, 512  16         ['res3b_branch2f[0][0]']
#  ion)                           )
#
#  bn3b_branch1 (BatchNormalizati  (None, 7, 7, 4, 512  16         ['res3b_branch1[0][0]']
#  on)                            )
#
#  add_6 (Add)                    (None, 7, 7, 4, 512  0           ['bn3b_branch2f[0][0]',
#                                 )                                 'bn3b_branch1[0][0]']
#
#  activation_19 (Activation)     (None, 7, 7, 4, 512  0           ['add_6[0][0]']
#                                 )
#
#  res4a_branch2a (Conv3D)        (None, 4, 4, 2, 256  131328      ['activation_19[0][0]']
#                                 )
#
#  bn4a_branch2a (BatchNormalizat  (None, 4, 4, 2, 256  8          ['res4a_branch2a[0][0]']
#  ion)                           )
#
#  activation_20 (Activation)     (None, 4, 4, 2, 256  0           ['bn4a_branch2a[0][0]']
#                                 )
#
#  res4a_branch2b (Conv3D)        (None, 4, 4, 2, 256  590080      ['activation_20[0][0]']
#                                 )
#
#  res4a_branch2c (Conv3D)        (None, 4, 4, 2, 256  590080      ['activation_20[0][0]']
#                                 )
#
#  res4a_branch2d (Conv3D)        (None, 4, 4, 2, 256  590080      ['activation_20[0][0]']
#                                 )
#
#  bn4a_branch2b (BatchNormalizat  (None, 4, 4, 2, 256  8          ['res4a_branch2b[0][0]']
#  ion)                           )
#
#  bn4a_branch2c (BatchNormalizat  (None, 4, 4, 2, 256  8          ['res4a_branch2c[0][0]']
#  ion)                           )
#
#  bn4a_branch2d (BatchNormalizat  (None, 4, 4, 2, 256  8          ['res4a_branch2d[0][0]']
#  ion)                           )
#
#  activation_21 (Activation)     (None, 4, 4, 2, 256  0           ['bn4a_branch2b[0][0]']
#                                 )
#
#  activation_22 (Activation)     (None, 4, 4, 2, 256  0           ['bn4a_branch2c[0][0]']
#                                 )
#
#  activation_23 (Activation)     (None, 4, 4, 2, 256  0           ['bn4a_branch2d[0][0]']
#                                 )
#
#  res4a_branch2bs (Conv3D)       (None, 4, 4, 2, 256  196864      ['activation_21[0][0]']
#                                 )
#
#  res4a_branch2cs (Conv3D)       (None, 4, 4, 2, 256  196864      ['activation_22[0][0]']
#                                 )
#
#  res4a_branch2ds (Conv3D)       (None, 4, 4, 2, 256  196864      ['activation_23[0][0]']
#                                 )
#
#  bn4a_branch2bs (BatchNormaliza  (None, 4, 4, 2, 256  8          ['res4a_branch2bs[0][0]']
#  tion)                          )
#
#  bn4a_branch2cs (BatchNormaliza  (None, 4, 4, 2, 256  8          ['res4a_branch2cs[0][0]']
#  tion)                          )
#
#  bn4a_branch2ds (BatchNormaliza  (None, 4, 4, 2, 256  8          ['res4a_branch2ds[0][0]']
#  tion)                          )
#
#  add_7 (Add)                    (None, 4, 4, 2, 256  0           ['activation_21[0][0]',
#                                 )                                 'bn4a_branch2bs[0][0]']
#
#  add_8 (Add)                    (None, 4, 4, 2, 256  0           ['activation_22[0][0]',
#                                 )                                 'bn4a_branch2cs[0][0]']
#
#  add_9 (Add)                    (None, 4, 4, 2, 256  0           ['bn4a_branch2ds[0][0]',
#                                 )                                 'activation_23[0][0]']
#
#  add_10 (Add)                   (None, 4, 4, 2, 256  0           ['add_7[0][0]',
#                                 )                                 'add_8[0][0]',
#                                                                   'add_9[0][0]']
#
#  activation_24 (Activation)     (None, 4, 4, 2, 256  0           ['add_10[0][0]']
#                                 )
#
#  res4a_branch2f (Conv3D)        (None, 4, 4, 2, 102  263168      ['activation_24[0][0]']
#                                 4)
#
#  res4a_branch1 (Conv3D)         (None, 4, 4, 2, 102  525312      ['activation_19[0][0]']
#                                 4)
#
#  bn4a_branch2f (BatchNormalizat  (None, 4, 4, 2, 102  8          ['res4a_branch2f[0][0]']
#  ion)                           4)
#
#  bn4a_branch1 (BatchNormalizati  (None, 4, 4, 2, 102  8          ['res4a_branch1[0][0]']
#  on)                            4)
#
#  add_11 (Add)                   (None, 4, 4, 2, 102  0           ['bn4a_branch2f[0][0]',
#                                 4)                                'bn4a_branch1[0][0]']
#
#  activation_25 (Activation)     (None, 4, 4, 2, 102  0           ['add_11[0][0]']
#                                 4)
#
#  res4b_branch2a (Conv3D)        (None, 4, 4, 2, 256  262400      ['activation_25[0][0]']
#                                 )
#
#  bn4b_branch2a (BatchNormalizat  (None, 4, 4, 2, 256  8          ['res4b_branch2a[0][0]']
#  ion)                           )
#
#  activation_26 (Activation)     (None, 4, 4, 2, 256  0           ['bn4b_branch2a[0][0]']
#                                 )
#
#  res4b_branch2b (Conv3D)        (None, 4, 4, 2, 256  590080      ['activation_26[0][0]']
#                                 )
#
#  res4b_branch2c (Conv3D)        (None, 4, 4, 2, 256  590080      ['activation_26[0][0]']
#                                 )
#
#  res4b_branch2d (Conv3D)        (None, 4, 4, 2, 256  590080      ['activation_26[0][0]']
#                                 )
#
#  bn4b_branch2b (BatchNormalizat  (None, 4, 4, 2, 256  8          ['res4b_branch2b[0][0]']
#  ion)                           )
#
#  bn4b_branch2c (BatchNormalizat  (None, 4, 4, 2, 256  8          ['res4b_branch2c[0][0]']
#  ion)                           )
#
#  bn4b_branch2d (BatchNormalizat  (None, 4, 4, 2, 256  8          ['res4b_branch2d[0][0]']
#  ion)                           )
#
#  activation_27 (Activation)     (None, 4, 4, 2, 256  0           ['bn4b_branch2b[0][0]']
#                                 )
#
#  activation_28 (Activation)     (None, 4, 4, 2, 256  0           ['bn4b_branch2c[0][0]']
#                                 )
#
#  activation_29 (Activation)     (None, 4, 4, 2, 256  0           ['bn4b_branch2d[0][0]']
#                                 )
#
#  res4b_branch2bs (Conv3D)       (None, 4, 4, 2, 256  196864      ['activation_27[0][0]']
#                                 )
#
#  res4b_branch2cs (Conv3D)       (None, 4, 4, 2, 256  196864      ['activation_28[0][0]']
#                                 )
#
#  res4b_branch2ds (Conv3D)       (None, 4, 4, 2, 256  196864      ['activation_29[0][0]']
#                                 )
#
#  bn4b_branch2bs (BatchNormaliza  (None, 4, 4, 2, 256  8          ['res4b_branch2bs[0][0]']
#  tion)                          )
#
#  bn4b_branch2cs (BatchNormaliza  (None, 4, 4, 2, 256  8          ['res4b_branch2cs[0][0]']
#  tion)                          )
#
#  bn4b_branch2ds (BatchNormaliza  (None, 4, 4, 2, 256  8          ['res4b_branch2ds[0][0]']
#  tion)                          )
#
#  add_12 (Add)                   (None, 4, 4, 2, 256  0           ['activation_27[0][0]',
#                                 )                                 'bn4b_branch2bs[0][0]']
#
#  add_13 (Add)                   (None, 4, 4, 2, 256  0           ['activation_28[0][0]',
#                                 )                                 'bn4b_branch2cs[0][0]']
#
#  add_14 (Add)                   (None, 4, 4, 2, 256  0           ['bn4b_branch2ds[0][0]',
#                                 )                                 'activation_29[0][0]']
#
#  add_15 (Add)                   (None, 4, 4, 2, 256  0           ['add_12[0][0]',
#                                 )                                 'add_13[0][0]',
#                                                                   'add_14[0][0]']
#
#  activation_30 (Activation)     (None, 4, 4, 2, 256  0           ['add_15[0][0]']
#                                 )
#
#  res4b_branch2f (Conv3D)        (None, 4, 4, 2, 102  263168      ['activation_30[0][0]']
#                                 4)
#
#  res4b_branch1 (Conv3D)         (None, 4, 4, 2, 102  1049600     ['activation_25[0][0]']
#                                 4)
#
#  bn4b_branch2f (BatchNormalizat  (None, 4, 4, 2, 102  8          ['res4b_branch2f[0][0]']
#  ion)                           4)
#
#  bn4b_branch1 (BatchNormalizati  (None, 4, 4, 2, 102  8          ['res4b_branch1[0][0]']
#  on)                            4)
#
#  add_16 (Add)                   (None, 4, 4, 2, 102  0           ['bn4b_branch2f[0][0]',
#                                 4)                                'bn4b_branch1[0][0]']
#
#  activation_31 (Activation)     (None, 4, 4, 2, 102  0           ['add_16[0][0]']
#                                 4)
#
#  avg_pool (AveragePooling3D)    (None, 1, 1, 1, 102  0           ['activation_31[0][0]']
#                                 4)
#
#  flatten_1 (Flatten)            (None, 1024)         0           ['avg_pool[0][0]']
#
#  fc12 (Dense)                   (None, 1000)         1025000     ['flatten_1[0][0]']
#
#  fc22 (Dense)                   (None, 2)            2002        ['fc12[0][0]']
#
# ==================================================================================================
# Total params: 10,105,386
# Trainable params: 10,104,946
# Non-trainable params: 440
# __________________________________________________________________________________________________

# %%
#two classes labesl
labels0 ={0:'abnormal', 1:'normal'}

# %%
#0normal videos from 0 to 39
#fighting videos from 40 to 54
#shooting videos from 55 to 69
#vandalism videos from 70 to 84
path =Test_videos[45]
path
# Out:
# 'sample_images_RA/fighting/2Fighting007_x264'

# %%
images = os.listdir(path)
vid = []
for img in images:
    img_path=path +"/"+img
    img2 = cv2.imread(img_path)
    img2= cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
    vid.append(cv2.resize(img2, (112, 112)))
vid = np.array(vid, dtype=np.float32)

# %%
result=[]
length =len(vid)
for i in range(0,len(vid),32):
    if i+32<=length:
        X = vid[i:i+32].transpose((1,2,0,3))
        output = model.predict_on_batch(np.array([X]))
        result.append(labels0[np.argmax(output)])
        print(output,labels0[np.argmax(output)])
# Out:
# [[0.5006589 0.4993411]] abnormal
# [[0.49969202 0.5003079 ]] normal
# [[0.49773777 0.5022622 ]] normal
# [[0.5020863  0.49791372]] abnormal
# [[0.50569373 0.49430627]] abnormal
# [[0.4945318  0.50546813]] normal
# [[0.49937084 0.5006291 ]] normal
# [[0.5042879  0.49571213]] abnormal
# [[0.5015161 0.4984839]] abnormal
# [[0.5042791  0.49572095]] abnormal
# [[0.4990791  0.50092083]] normal
# [[0.50060254 0.49939746]] abnormal
# [[0.49805924 0.5019408 ]] normal
# [[0.5063648  0.49363512]] abnormal
# [[0.5003401  0.49965984]] abnormal
# [[0.5030553 0.4969447]] abnormal
# [[0.50181127 0.4981888 ]] abnormal
# [[0.49956366 0.5004363 ]] normal
# [[0.49655557 0.5034444 ]] normal
# [[0.49598098 0.504019  ]] normal
# [[0.494942 0.505058]] normal
# [[0.4996243 0.5003757]] normal
# [[0.50211734 0.49788263]] abnormal
# [[0.49986333 0.50013673]] normal
# [[0.49795   0.5020499]] normal
# [[0.50456405 0.49543592]] abnormal
# [[0.5022581  0.49774188]] abnormal
# [[0.5019445  0.49805543]] abnormal
# [[0.50562644 0.4943735 ]] abnormal
# [[0.50193137 0.4980687 ]] abnormal
# [[0.501936   0.49806398]] abnormal
# [[0.5027392  0.49726072]] abnormal
# [[0.49912336 0.5008766 ]] normal
# [[0.49736997 0.50263   ]] normal
# [[0.49833155 0.5016685 ]] normal
# [[0.5020413  0.49795875]] abnormal
# [[0.50002515 0.49997485]] abnormal
# [[0.50116163 0.49883834]] abnormal
# [[0.49707994 0.50292003]] normal
# [[0.5007513 0.4992487]] abnormal
# [[0.5020694  0.49793056]] abnormal
# [[0.4989833 0.5010168]] normal
# [[0.50420934 0.49579072]] abnormal
# [[0.50356543 0.49643463]] abnormal
# [[0.5034192  0.49658087]] abnormal
# [[0.5011768 0.4988232]] abnormal
# [[0.50018257 0.4998175 ]] abnormal
# [[0.5047862  0.49521378]] abnormal
# [[0.50056994 0.4994301 ]] abnormal
# [[0.50154376 0.49845627]] abnormal
# [[0.5033281  0.49667192]] abnormal
# [[0.50390786 0.49609208]] abnormal
# [[0.5028184 0.4971816]] abnormal
# [[0.503069   0.49693108]] abnormal
# [[0.50184757 0.49815246]] abnormal
# [[0.5023125  0.49768755]] abnormal
# [[0.5019004 0.4980996]] abnormal
# [[0.5015644  0.49843565]] abnormal
# [[0.50474715 0.49525288]] abnormal

# %%
result
# Out:
# ['abnormal',
#  'abnormal',
#  'abnormal',
#  'abnormal',
#  'abnormal',
#  'abnormal',
#  'abnormal']
